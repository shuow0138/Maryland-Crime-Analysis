# %%
import requests
import pandas as pd
import json

# %%
res = requests.get("https://opendata.maryland.gov/resource/2p5g-xrcb.json")

# %%
vio_data = pd.read_json(json.dumps(res.json()))

# %%
vio_data
# Out:
#     jurisdiction    county  year  population  murder  rape  robbery  \
# 0       Aberdeen   Harford  1990       13087       1     1       26
# 1       Aberdeen   Harford  1991       13301       0     6       14
# 2       Aberdeen   Harford  1992       13432       0     8       18
# 3       Aberdeen   Harford  1993       13703       0    12       16
# 4       Aberdeen   Harford  1994       13815       0     3       16
# ..           ...       ...   ...         ...     ...   ...      ...
# 995    Deer Park   Garrett  2014         390       0     0        0
# 996    Deer Park   Garrett  2015         390       0     0        0
# 997    Deer Park   Garrett  2016         390       0     0        0
# 998    Deer Park   Garrett  2017         390       0     0        0
# 999       Delmar  Wicomico  1990        1430       0     1        0
#
#      agg_assault  b_e  larceny_theft  ...  agg_assault_per_100_000_people  \
# 0             58  236            542  ...                           443.2
# ...
